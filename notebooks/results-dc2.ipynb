# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210421', 'dc2_20210422', 'dc2_20210601', 'dc2_20210606']
h2_find2, h2_findq = load_results(h2_run_ids)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00), (0.05, 10000)])
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)   Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN  1021.308197   986.341291      0.690373     0.099869
# 3  FindQ    0.00    0.9   819.975545          NaN      0.950000          NaN
# 4  FindQ    0.05    0.0   541.869310  1131.437634      0.841333     0.073806
# 1  FindQ    0.05    0.9   182.094766   417.346541      0.800303     0.114882
# 2  FindQ    0.10    0.9   253.570654   283.017533      0.781297     0.108978
#
#     N
# 0  29
# 3   1
# 4  11
# 1  14
# 2  13

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['dc2_start3_20210421', 'dc2_start3_20210422']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma   Time (mean)    Time (std)  Match (mean)  \
# 0  Find2     NaN    NaN  11993.589527  19316.352909      0.594951
# 1  FindQ    0.05    0.9    150.700218    255.809798      0.623180
# 2  FindQ    0.10    0.9    201.460535    380.172016      0.609248
#
#    Match (std)  N
# 0     0.069267  8
# 1     0.082980  8
# 2     0.081436  8
