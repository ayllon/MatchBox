# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210610', 'dc2_gamma0_20210610', 'dc2_lambda0_20210610', 'dc2_gamma0_20210611']
h2_find2, h2_findq = load_results(h2_run_ids)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 1000, 0)])
h2_stats
# Out:
#     Method  Lambda  Gamma      Time Q1      Time Q2      Time Q3  Match Q1  \
# 0    Find2     NaN    NaN   133.346605   599.224696  1445.192889  0.600000
# 3  FindQ 0    0.00    0.9  2419.651199  2419.651199  2419.651199  0.950000
# 4  FindQ 0    0.05    0.0    41.885177    50.858871    87.918350  0.823529
# 1  FindQ 0    0.05    0.9    18.963919    31.187560    42.928707  0.789474
# 2  FindQ 0    0.10    0.9    19.652185    40.100813    49.664439  0.761905
#
#    Match Q2  Match Q3  Card Q1  Card Q2  Card Q3   N
# 0  0.666667  0.750000     65.0     90.0    146.5  39
# 3  0.950000  0.950000     50.0     50.0     50.0   1
# 4  0.888889  0.909091     43.0     55.0     83.0  21
# 1  0.833333  0.857143     35.0     39.0     74.0  13
# 2  0.800000  0.842105     38.0     69.0    104.0  13

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['dc2_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#     Method  Lambda  Gamma      Time Q1      Time Q2       Time Q3  Match Q1  \
# 0    Find2     NaN    NaN  4263.335629  6483.542012  21748.237648  0.513158
# 1  FindQ 0    0.05    0.9    12.314728    38.894235    253.581916  0.589474
# 2  FindQ 0    0.10    0.9    13.431637   103.863648    241.289539  0.589474
#
#    Match Q2  Match Q3  Card Q1  Card Q2  Card Q3  N
# 0  0.555556  0.622807    132.5    224.0    285.5  7
# 1  0.666667  0.724458     77.5    116.0    165.5  7
# 2  0.631579  0.694444     81.0    127.0    192.5  7
