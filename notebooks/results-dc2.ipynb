# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = 'euclid_cosmos_DC2_S2_v2.1_calib.fits_euclid_cosmos_DC2_S2_v2.1_valid.fits_20210119'
h2_find2, h2_findq = load_results(h2_run_id)

# %%
plot.plot_comparison(h2_find2, h2_findq)

# %%
h2_stats = general_stats(h2_find2, h2_findq)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)   Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN  1980.085869  2656.346931      0.675231     0.117814
# 1  FindQ    0.10    0.9   206.515957   321.443433      0.789757     0.112628
# 2  FindQ    0.05    0.9   304.522625   559.642189      0.802190     0.101641
#
#     N
# 0  12
# 1  10
# 2  12

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'euclid_cosmos_DC2_S2_v2.1_calib.fits_euclid_cosmos_DC2_S2_v2.1_valid.fits_3ind_20210204'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq)
h3_stats
