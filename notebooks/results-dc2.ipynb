# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats, pretty_highest_ind
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210628', 'dc2_20210629', 'dc2_20210709'] + ['dc2_20210610', 'dc2_gamma0_20210610', 'dc2_lambda0_20210610', 'dc2_gamma0_20210611']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/dc2-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#     Method  Lambda  Gamma     Time Q1      Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN  121.539101  1499.961126  0.604762  0.750000
# 1  FindQ 0    0.05    0.9   20.723543   177.130021  0.786550  0.879934
# 2  FindQ 0    0.10    0.9   14.967693    76.909608  0.758929  0.856250
# 3  FindQ 1    0.05    0.9  174.612389  2861.827431  0.851190  0.907143
#
#    Card Q1  Card Q3  Precision    Overhead   N
# 0    72.50    173.0   0.900983  322.486225  54
# 1    38.75    136.0   0.223622   28.687352  24
# 2    37.75     96.5   0.370181   19.824526  20
# 3   260.50   1271.0   0.194233   11.595732  12

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, findq_subset)

# %%
fig_bootstrap_2.savefig('/home/aalvarez/Downloads/bootstrap_dc2.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Maximal EDD found

# %%
pretty_highest_ind(ind_find2)
# Out:
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 1                           FLUXERR_G_1                          FLUXERR_G_1
# 2                           FLUXERR_I_1                          FLUXERR_I_1
# 3                           FLUXERR_R_1                          FLUXERR_R_1
# 4                           FLUXERR_VIS                          FLUXERR_VIS
# 5                           FLUXERR_Z_1                          FLUXERR_Z_1
# 6                              FLUX_G_1                             FLUX_G_1
# 7                              FLUX_H_1                             FLUX_H_1
# 8                              FLUX_I_1                             FLUX_I_1
# 9                              FLUX_J_1                             FLUX_J_1
# 10                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 11                             FLUX_R_1                             FLUX_R_1
# 12                             FLUX_VIS                             FLUX_VIS
# 13                             FLUX_Y_1                             FLUX_Y_1
# 14                             FLUX_Z_1                             FLUX_Z_1
# 15                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 16                                   ID                                   ID
# 17                        MU_MAX_DETECT                        MU_MAX_DETECT
# 18                 MU_THRESHOLD_DETECT)                  MU_THRESHOLD_DETECT

# %%
for k in findq_subset:
    print(k)
    print(pretty_highest_ind(ind_findq[k]))
# Out:
# (0.05, 1.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_R_1                          FLUXERR_R_1
# 6                           FLUXERR_VIS                          FLUXERR_VIS
# 7                           FLUXERR_Y_1                          FLUXERR_Y_1
# 8                           FLUXERR_Z_1                          FLUXERR_Z_1
# 9                              FLUX_G_1                             FLUX_G_1
# 10                             FLUX_H_1                             FLUX_H_1
# 11                             FLUX_I_1                             FLUX_I_1
# 12                             FLUX_J_1                             FLUX_J_1
# 13                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 14                             FLUX_R_1                             FLUX_R_1
# 15                             FLUX_VIS                             FLUX_VIS
# 16                             FLUX_Y_1                             FLUX_Y_1
# 17                             FLUX_Z_1                             FLUX_Z_1
# 18                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 19                       MU_MAX_DETECT)                        MU_MAX_DETECT
# (0.1, 1.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_R_1                          FLUXERR_R_1
# 6                           FLUXERR_VIS                          FLUXERR_VIS
# 7                           FLUXERR_Y_1                          FLUXERR_Y_1
# 8                           FLUXERR_Z_1                          FLUXERR_Z_1
# 9                              FLUX_G_1                             FLUX_G_1
# 10                             FLUX_H_1                             FLUX_H_1
# 11                             FLUX_I_1                             FLUX_I_1
# 12                             FLUX_J_1                             FLUX_J_1
# 13                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 14                             FLUX_R_1                             FLUX_R_1
# 15                             FLUX_VIS                             FLUX_VIS
# 16                             FLUX_Y_1                             FLUX_Y_1
# 17                             FLUX_Z_1                             FLUX_Z_1
# 18                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 19                       MU_MAX_DETECT)                        MU_MAX_DETECT
# (0.05, 1.0, 1)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_I_1                          FLUXERR_I_1
# 4                           FLUXERR_R_1                          FLUXERR_R_1
# 5                           FLUXERR_VIS                          FLUXERR_VIS
# 6                           FLUXERR_Y_1                          FLUXERR_Y_1
# 7                           FLUXERR_Z_1                          FLUXERR_Z_1
# 8                              FLUX_H_1                             FLUX_J_1
# 9                              FLUX_I_1                             FLUX_I_1
# 10                             FLUX_J_1                             FLUX_H_1
# 11                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 12                             FLUX_R_1                             FLUX_R_1
# 13                             FLUX_VIS                             FLUX_VIS
# 14                             FLUX_Y_1                             FLUX_Y_1
# 15                             FLUX_Z_1                             FLUX_Z_1
# 16                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 17                                   ID                                   ID
# 18                        MU_MAX_DETECT                        MU_MAX_DETECT
# 19                 MU_THRESHOLD_DETECT)                  MU_THRESHOLD_DETECT

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['dc2_start3_20210709', 'dc2_start3_20210715']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#     Method  Lambda  Gamma     Time Q1      Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN   48.627372  1456.598912  0.656250  0.875000
# 1  FindQ 0    0.05    0.9   88.546557  1937.186500  0.727273  0.809524
# 2  FindQ 0    0.10    0.9  214.217182  5460.426909  0.726010  0.800000
# 3  FindQ 1    0.05    0.9   96.309481  2860.746901  0.722222  0.807143
#
#    Card Q1  Card Q3  Precision  Overhead   N
# 0    176.5    316.0   0.998383  6.191409   3
# 1    184.0    406.0   0.864489  5.736808  33
# 2    198.0    445.0   0.867720  7.980047  28
# 3    266.5    609.0   0.872336  2.145448  34

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, findq_subset, alphas=[0.1])

# %%
fig_bootstrap_3.savefig('/home/aalvarez/Downloads/bootstrap_dc2_start3.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
