# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210421', 'dc2_20210422']
h2_find2, h2_findq = load_results(h2_run_ids)
findq_subset = [(0.05, 1.00), (0.10, 1.00), (0.05, 1.10), (0.10, 1.10)]

# %%
plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, alpha=0.05)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)   Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN  5204.458085  5571.595809      0.780204     0.103976
# 5  FindQ    0.01  0.925   508.644396  1077.325723      0.917528     0.059515
# 7  FindQ    0.01  0.945   714.608390  1535.549643      0.911057     0.068838
# 2  FindQ    0.01  0.950   497.344309  1007.656216      0.899152     0.068905
# 3  FindQ    0.05  0.925   220.982047   354.072415      0.923377     0.074073
# 6  FindQ    0.05  0.945   550.446159  1039.039934      0.858465     0.107670
# 4  FindQ    0.05  0.950   485.473611   844.460975      0.841624     0.102372
# 9  FindQ    0.10  0.925  4096.789834  8849.160264      0.908339     0.089859
# 1  FindQ    0.10  0.945  1939.693637  4148.957533      0.842875     0.101289
# 8  FindQ    0.10  0.950  1389.523050  2344.502896      0.842098     0.092345
#
#     N
# 0  14
# 5   8
# 7   8
# 2   8
# 3   7
# 6  13
# 4  14
# 9   7
# 1  13
# 8  13

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['dc2_start3_20210421', 'dc2_start3_20210422']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma   Time (mean)    Time (std)  Match (mean)  \
# 0  Find2     NaN    NaN  11993.589527  19316.352909      0.594951
# 3  FindQ    0.05   0.89    192.610493    346.863742      0.623180
# 1  FindQ    0.05   0.90    150.700218    255.809798      0.623180
# 4  FindQ    0.10   0.89    198.114206    357.530023      0.609248
# 2  FindQ    0.10   0.90    201.460535    380.172016      0.609248
#
#    Match (std)  N
# 0     0.069267  8
# 3     0.082980  8
# 1     0.082980  8
# 4     0.081436  8
# 2     0.081436  8
