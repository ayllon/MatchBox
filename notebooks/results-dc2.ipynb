# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import plot
from results import load_results, general_stats, pretty_highest_ind

plt.style.use('seaborn')
plt.style.use('seaborn-paper')
plt.style.use('tableau-colorblind10')
plt.rcParams.update({
    'figure.figsize': (7.2, 3.5),
    'text.usetex': True,
    'legend.borderpad': 0,
    'xtick.bottom': True,
    'xtick.major.size': 2,
    'xtick.minor.size': 1,
    'lines.markersize': 3,
    'lines.linewidth': 0.5,
    'errorbar.capsize': 4,
    'lines.markeredgewidth': 0.8
})

style_cycler = plot.StyleCycler(['o', 's', 'D', '*'], ['--'],  plt.rcParams['axes.prop_cycle'])

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210930', 'dc2_20211004', 'dc2_20211006']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
fig.savefig('/home/aalvarez/Downloads/dc2-absolute-dist.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq)
h2_stats
# Out:
#     Method  Lambda  Gamma      Time Q1      Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN    74.944340   805.705801  0.600000  0.710084
# 4  FindQ 0    0.00    0.9   254.175384   254.175384  0.695652  0.695652
# 1  FindQ 0    0.05    0.0    33.473964   209.956059  0.812500  0.938690
# 3  FindQ 0    0.05    0.9    25.566274   214.257173  0.764610  0.894737
# 2  FindQ 0    0.10    0.9    18.614805   144.984849  0.758929  0.872222
# 7  FindQ 1    0.00    0.9  1819.059254  1819.059254  0.782609  0.782609
# 5  FindQ 1    0.05    0.0          NaN          NaN       NaN       NaN
# 6  FindQ 1    0.05    0.9   458.260928  1881.017765  0.813025  0.925000
# 8  FindQ 1    0.10    0.9   285.489794  1320.006447  0.789474  0.894737
#
#    Card Q1  Card Q3  Precision    Overhead     N  Timeouts
# 0    73.00   149.50   0.897403  146.243523  35.0  0.339623
# 4    53.00    53.00   0.010625  186.452830   1.0  0.857143
# 1    42.50   102.25   0.109248   36.075915  10.0  0.090909
# 3    45.75   112.75   0.142162   29.750412  46.0  0.132075
# 2    42.00    98.00   0.180900   23.813304  40.0  0.230769
# 7   109.00   109.00   0.004587  364.000000   1.0  0.833333
# 5      NaN      NaN        NaN         NaN   NaN  9.000000
# 6   517.50   797.50   0.225082   11.468440  26.0  0.500000
# 8   372.00   613.00   0.209245    9.777792  21.0  0.571429

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
fig_bootstrap_2.savefig('/home/aalvarez/Downloads/dc2-relative.pdf')

# %% [markdown]
# ## Maximal EDD found

# %%
pretty_highest_ind(ind_find2)
# Out:
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                           FLUXERR_G_1                          FLUXERR_G_1
# 2                           FLUXERR_I_1                          FLUXERR_I_1
# 3                           FLUXERR_R_1                          FLUXERR_R_1
# 4                           FLUXERR_VIS                          FLUXERR_VIS
# 5                           FLUXERR_Z_1                          FLUXERR_Z_1
# 6                              FLUX_G_1                             FLUX_G_1
# 7                              FLUX_I_1                             FLUX_I_1
# 8                              FLUX_J_1                             FLUX_J_1
# 9                    FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 10                             FLUX_R_1                             FLUX_R_1
# 11                             FLUX_VIS                             FLUX_VIS
# 12                             FLUX_Y_1                             FLUX_Y_1
# 13                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 14                                   ID                                   ID
# 15                        MU_MAX_DETECT                        MU_MAX_DETECT
# 16                  MU_THRESHOLD_DETECT                  MU_THRESHOLD_DETECT

# %%
for k in ind_findq.keys():
    print(k)
    print(pretty_highest_ind(ind_findq[k]))
# Out:
# (0.05, 1000.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_R_1                          FLUXERR_R_1
# 6                           FLUXERR_Y_1                          FLUXERR_Y_1
# 7                           FLUXERR_Z_1                          FLUXERR_Z_1
# 8                              FLUX_G_1                             FLUX_G_1
# 9                              FLUX_H_1                             FLUX_H_1
# 10                             FLUX_I_1                             FLUX_I_1
# 11                             FLUX_J_1                             FLUX_J_1
# 12                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 13                             FLUX_R_1                             FLUX_R_1
# 14                             FLUX_VIS                             FLUX_VIS
# 15                             FLUX_Y_1                             FLUX_Y_1
# 16                             FLUX_Z_1                             FLUX_Z_1
# 17                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 18                        MU_MAX_DETECT                        MU_MAX_DETECT
# 19                  MU_THRESHOLD_DETECT                  MU_THRESHOLD_DETECT
# (0.1, 1.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_R_1                          FLUXERR_R_1
# 6                           FLUXERR_VIS                          FLUXERR_VIS
# 7                           FLUXERR_Y_1                          FLUXERR_Y_1
# 8                           FLUXERR_Z_1                          FLUXERR_Z_1
# 9                              FLUX_G_1                             FLUX_G_1
# 10                             FLUX_H_1                             FLUX_H_1
# 11                             FLUX_I_1                             FLUX_I_1
# 12                             FLUX_J_1                             FLUX_J_1
# 13                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 14                             FLUX_R_1                             FLUX_R_1
# 15                             FLUX_VIS                             FLUX_VIS
# 16                             FLUX_Y_1                             FLUX_Y_1
# 17                             FLUX_Z_1                             FLUX_Z_1
# 18                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 19                                   ID                                   ID
# 20                        MU_MAX_DETECT                        MU_MAX_DETECT
# 21                  MU_THRESHOLD_DETECT                  MU_THRESHOLD_DETECT
# (0.05, 1.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_R_1                          FLUXERR_R_1
# 6                           FLUXERR_VIS                          FLUXERR_VIS
# 7                           FLUXERR_Y_1                          FLUXERR_Y_1
# 8                           FLUXERR_Z_1                          FLUXERR_Z_1
# 9                              FLUX_G_1                             FLUX_G_1
# 10                             FLUX_H_1                             FLUX_H_1
# 11                             FLUX_I_1                             FLUX_I_1
# 12                             FLUX_J_1                             FLUX_J_1
# 13                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 14                             FLUX_R_1                             FLUX_R_1
# 15                             FLUX_VIS                             FLUX_VIS
# 16                             FLUX_Y_1                             FLUX_Y_1
# 17                             FLUX_Z_1                             FLUX_Z_1
# 18                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 19                                   ID                                   ID
# 20                        MU_MAX_DETECT                        MU_MAX_DETECT
# 21                  MU_THRESHOLD_DETECT                  MU_THRESHOLD_DETECT
# (0.0, 1.0, 0)
#    euclid_cosmos_DC2_S2_v2.1_calib.fits euclid_cosmos_DC2_S2_v2.1_valid.fits
# 0                     CLASS_STAR_DETECT                    CLASS_STAR_DETECT
# 1                    ELLIPTICITY_DETECT                   ELLIPTICITY_DETECT
# 2                           FLUXERR_G_1                          FLUXERR_G_1
# 3                           FLUXERR_H_1                          FLUXERR_H_1
# 4                           FLUXERR_I_1                          FLUXERR_I_1
# 5                           FLUXERR_J_1                          FLUXERR_J_1
# 6                           FLUXERR_R_1                          FLUXERR_R_1
# 7                           FLUXERR_VIS                          FLUXERR_VIS
# 8                           FLUXERR_Y_1                          FLUXERR_Y_1
# 9                           FLUXERR_Z_1                          FLUXERR_Z_1
# 10                             FLUX_G_1                             FLUX_G_1
# 11                             FLUX_I_1                             FLUX_I_1
# 12                             FLUX_J_1                             FLUX_J_1
# 13                   FLUX_RADIUS_DETECT                   FLUX_RADIUS_DETECT
# 14                             FLUX_R_1                             FLUX_R_1
# 15                             FLUX_VIS                             FLUX_VIS
# 16                             FLUX_Z_1                             FLUX_Z_1
# 17                    FWHM_IMAGE_DETECT                    FWHM_IMAGE_DETECT
# 18                                   ID                                   ID
# 19                        MU_MAX_DETECT                        MU_MAX_DETECT
# 20                  MU_THRESHOLD_DETECT                  MU_THRESHOLD_DETECT
# (0.05, 1000.0, 1)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 for k in ind_findq.keys():
#       2     print(k)
# ----> 3     print(pretty_highest_ind(ind_findq[k]))
#
# File ~/Work/Projects/MatchBox/notebooks/results.py:211, in pretty_highest_ind(inds, topn, max_ind)
#     209     df.sort_values(by=0, axis='columns', inplace=True)
#     210     dfs.append(df)
# --> 211 return dfs if topn > 1 else dfs[0]
#
# IndexError: list index out of range

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['dc2_start3_20210930']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
fig3.savefig('/home/aalvarez/Downloads/dc2-start3-absolute.pdf')

# %%
h3_stats = general_stats(h3_find2, h3_findq)
h3_stats
# Out:
#     Method  Lambda  Gamma     Time Q1     Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN         NaN         NaN       NaN       NaN
# 2  FindQ 0    0.05    0.9   41.255338  139.873523  0.729102  0.820588
# 1  FindQ 0    0.10    0.9  265.763552  866.401951  0.700464  0.768382
# 3  FindQ 1    0.05    0.9  201.962701  540.782536  0.721362  0.809598
# 4  FindQ 1    0.10    0.9  449.151049  912.877266  0.695046  0.764706
#
#    Card Q1  Card Q3  Precision  Overhead    N  Timeouts
# 0      NaN      NaN        NaN       NaN  NaN      5.00
# 2   206.75   244.00   0.799662  1.725849  4.0      0.00
# 1   246.50   301.25   0.719479  4.254722  4.0      0.00
# 3   360.00   569.50   0.816750  1.448601  3.0      0.25
# 4   393.00   608.50   0.839216  1.356644  3.0      0.25

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)], alphas=[0.15])

# %%
fig_bootstrap_3.savefig('/home/aalvarez/Downloads/dc2-start3-relative.pdf')
