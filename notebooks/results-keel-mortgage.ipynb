# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210429', 'mortgage_20210601', 'mortgage_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 100000, 0)])
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN   0.467375    0.730781  0.750000       1.0     12.0
# 3  FindQ 0    0.00    0.9  78.524620  485.681265  1.000000       1.0     11.0
# 4  FindQ 0    0.05    0.0   0.826601   11.982216  0.875000       1.0     12.0
# 1  FindQ 0    0.05    0.9   0.810346   11.484500  0.875000       1.0     11.0
# 2  FindQ 0    0.10    0.9   0.787984    2.641932  0.866667       1.0     11.0
#
#    Card Q3  Precision     N
# 0     22.0   0.988136  1146
# 3     15.0   0.050115   197
# 4     17.0   0.477891   445
# 1     17.0   0.557392   502
# 2     18.0   0.739351   502

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['mortgage_start3_20210524', 'mortgage_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 1000, 0)])
h3_stats
# Out:
#     Method  Lambda  Gamma   Time Q1    Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN  2.257515   8.522939  0.750000       1.0     11.0
# 3  FindQ 0    0.00    0.9  3.792156  84.460852  0.875000       1.0     10.0
# 4  FindQ 0    0.05    0.0  2.471143  10.147569  0.785714       1.0     10.0
# 1  FindQ 0    0.05    0.9  2.092090   9.624108  0.806250       1.0     10.0
# 2  FindQ 0    0.10    0.9  2.270531  10.019897  0.812500       1.0     10.0
#
#    Card Q3  Precision    N
# 0     27.0   0.999914  187
# 3     15.0   0.343395  140
# 4     20.0   0.951561  140
# 1     20.0   0.999087  187
# 2     22.0   1.000000   47
