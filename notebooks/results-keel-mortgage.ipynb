# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = 'mortgage.dat_treasury.dat_20210112'
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN    20.437726   77.343529      0.854243     0.167990
# 1  FindQ    0.05    0.9     8.767012    9.875929      0.893759     0.166444
# 2  FindQ    0.10    0.9     4.422693    6.761647      0.882772     0.172282
#
#      N
# 0  296
# 1  146
# 2  146

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'mortgage.dat_treasury.dat_3ind_20210118'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)   Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   523.403249  1608.268771      0.850694     0.183315
# 1  FindQ    0.05    0.9     8.875953     4.064832      0.866319     0.161242
# 2  FindQ    0.10    0.9     9.145107     4.196349      0.861111     0.164122
#
#     N
# 0  12
# 1  12
# 2  12
