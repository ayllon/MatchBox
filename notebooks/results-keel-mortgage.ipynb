# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210429', 'mortgage_20210601', 'mortgage_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00), (0.05, 100000)])
h2_stats
# Out:
#   Method  Lambda  Gamma    Time Q1     Time Q2     Time Q3    Time IQR  \
# 0  Find2     NaN    NaN   0.467375    0.557355    0.730781    0.263406
# 3  FindQ    0.00    0.9  78.524620  237.937906  485.681265  407.156646
# 4  FindQ    0.05    0.0   0.826552    3.268558   11.967638   11.141086
# 1  FindQ    0.05    0.9   0.810346    1.002647   11.484500   10.674154
# 2  FindQ    0.10    0.9   0.787984    0.885873    2.641932    1.853947
#
#    Match Q1  Match Q2  Match Q3  Match IQR     N
# 0  0.750000  0.912879       1.0   0.250000  1146
# 3  1.000000  1.000000       1.0   0.000000   197
# 4  0.875000  0.937500       1.0   0.125000   446
# 1  0.875000  0.937500       1.0   0.125000   502
# 2  0.866667  0.937500       1.0   0.133333   502

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['mortgage_start3_20210524', 'mortgage_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00), (0.05, 1000)])
h3_stats
# Out:
#   Method  Lambda  Gamma   Time Q1    Time Q2    Time Q3   Time IQR  Match Q1  \
# 0  Find2     NaN    NaN  2.257515   6.718897   8.522939   6.265425  0.750000
# 3  FindQ    0.00    0.9  3.792156  49.160071  84.460852  80.668696  0.875000
# 4  FindQ    0.05    0.0  2.471143   7.932348  10.147569   7.676426  0.785714
# 1  FindQ    0.05    0.9  2.092090   7.499724   9.624108   7.532018  0.806250
# 2  FindQ    0.10    0.9  2.270531   7.998134  10.019897   7.749365  0.812500
#
#    Match Q2  Match Q3  Match IQR    N
# 0    0.9375       1.0   0.250000  187
# 3    1.0000       1.0   0.125000  140
# 4    0.9375       1.0   0.214286  140
# 1    0.9375       1.0   0.193750  187
# 2    0.9375       1.0   0.187500   47
