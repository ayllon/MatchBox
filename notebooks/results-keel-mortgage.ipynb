# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210429', 'mortgage_20210601', 'mortgage_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 100000, 0)])
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q2     Time Q3  Match Q1  \
# 0    Find2     NaN    NaN   0.467375    0.557355    0.730781  0.750000
# 3  FindQ 0    0.00    0.9  78.524620  237.937906  485.681265  1.000000
# 4  FindQ 0    0.05    0.0   0.826552    3.268558   11.967638  0.875000
# 1  FindQ 0    0.05    0.9   0.810346    1.002647   11.484500  0.875000
# 2  FindQ 0    0.10    0.9   0.787984    0.885873    2.641932  0.866667
#
#    Match Q2  Match Q3  Card Q1  Card Q2  Card Q3     N
# 0  0.912879       1.0    12.00     16.0     22.0  1146
# 3  1.000000       1.0    11.00     12.0     15.0   197
# 4  0.937500       1.0    11.25     14.0     17.0   446
# 1  0.937500       1.0    11.00     14.0     17.0   502
# 2  0.937500       1.0    11.00     14.0     18.0   502

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['mortgage_start3_20210524', 'mortgage_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 1000, 0)])
h3_stats
# Out:
#     Method  Lambda  Gamma   Time Q1    Time Q2    Time Q3  Match Q1  Match Q2  \
# 0    Find2     NaN    NaN  2.257515   6.718897   8.522939  0.750000    0.9375
# 3  FindQ 0    0.00    0.9  3.792156  49.160071  84.460852  0.875000    1.0000
# 4  FindQ 0    0.05    0.0  2.471143   7.932348  10.147569  0.785714    0.9375
# 1  FindQ 0    0.05    0.9  2.092090   7.499724   9.624108  0.806250    0.9375
# 2  FindQ 0    0.10    0.9  2.270531   7.998134  10.019897  0.812500    0.9375
#
#    Match Q3  Card Q1  Card Q2  Card Q3    N
# 0       1.0     11.0     15.0     27.0  187
# 3       1.0     10.0     11.0     15.0  140
# 4       1.0     10.0     13.0     20.0  140
# 1       1.0     10.0     13.0     20.0  187
# 2       1.0     10.0     14.0     22.0   47
