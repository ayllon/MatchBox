# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210429', 'mortgage_20210601', 'mortgage_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00), (0.05, 100000)])
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN     8.669673   34.793330      0.843824     0.177706
# 3  FindQ    0.00    0.9   294.426540  270.272886      0.962498     0.093047
# 4  FindQ    0.05    0.0     6.566537    6.860790      0.903726     0.150870
# 1  FindQ    0.05    0.9     5.955576    7.170429      0.911722     0.132053
# 2  FindQ    0.10    0.9     3.170717    5.095930      0.902352     0.136641
#
#       N
# 0  1146
# 3   197
# 4   446
# 1   502
# 2   502

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'mortgage_start3_20210524'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   104.075851  642.250353      0.857457     0.177090
# 1  FindQ    0.05    0.9     6.871707    5.298844      0.878480     0.162587
# 2  FindQ    0.10    0.9     6.967188    5.141468      0.875631     0.163235
#
#     N
# 0  47
# 1  47
# 2  47
