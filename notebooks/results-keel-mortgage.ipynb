# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats, pretty_highest_ind
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['mortgage_20210628'] + ['mortgage_20210429', 'mortgage_20210601', 'mortgage_20210606']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/mortgage-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN   0.464811    0.731456    0.7500       1.0    12.00
# 1  FindQ 0    0.05    0.9   0.805719   11.185262    0.8750       1.0    11.00
# 2  FindQ 0    0.10    0.9   0.785860    3.170416    0.8750       1.0    11.00
# 3  FindQ 1    0.05    0.9  35.880829  120.262094    0.9375       1.0   101.75
#
#    Card Q3  Precision   Overhead     N
# 0    22.00   0.988375  12.419707  1389
# 1    17.00   0.554093  17.985683   739
# 2    18.00   0.725245   8.130010   738
# 3   201.75   0.174029   8.781986   238

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, findq_subset)

# %%
fig_bootstrap_2.savefig('/home/aalvarez/Downloads/bootstrap_mortgage.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Maximal EDD found

# %%
pretty_highest_ind(ind_find2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-acf316a47466> in <module>
# ----> 1 pretty_highest_ind(ind_find2)
#
# NameError: name 'pretty_highest_ind' is not defined

# %%
for k in findq_subset:
    print(k)
    print(pretty_highest_ind(ind_findq[k]))

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['mortgage_start3_20210707']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats

# %%
fig3.savefig('/home/aalvarez/Downloads/mortgage_3ind-grow.pdf')

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, findq_subset)

# %%
fig_bootstrap_3.savefig('/home/aalvarez/Downloads/bootstrap_mortgage_start3.eps')
