# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats, pretty_highest_ind
import plot

plt.style.use('seaborn')
plt.style.use('seaborn-paper')
plt.style.use('tableau-colorblind10')
plt.rcParams.update({
    'figure.figsize': (4.8, 3),
    'text.usetex': True,
    'font.size': 10,
    'ytick.labelsize': 6,
    'xtick.labelsize': 6,
    'axes.labelsize': 10,
    'legend.fontsize': 10,
    'lines.markersize': 5,
    'lines.linewidth': 1,
    'errorbar.capsize': 2
})

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['mortgage_20211001']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
#fig.savefig('/home/aalvarez/Downloads/mortgage-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq)
h2_stats
# Out:
#     Method  Lambda  Gamma      Time Q1      Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN     0.444121     0.640070  0.750000  1.000000
# 4  FindQ 0    0.00    0.9   136.431227   510.874040  1.000000  1.000000
# 1  FindQ 0    0.05    0.0     0.840276     9.646955  0.888393  0.937500
# 3  FindQ 0    0.05    0.9     0.764468    10.605020  0.875000  1.000000
# 2  FindQ 0    0.10    0.9     0.734843     1.985103  0.842949  1.000000
# 7  FindQ 1    0.00    0.9   469.675079  2629.043405  1.000000  1.000000
# 5  FindQ 1    0.05    0.0  1134.089563  1972.301431  0.859375  0.953125
# 6  FindQ 1    0.05    0.9    47.103378   247.386208  0.875000  1.000000
# 8  FindQ 1    0.10    0.9    44.104542   266.323722  0.875000  1.000000
#
#    Card Q1  Card Q3  Precision    Overhead    N  Timeouts
# 0    12.00    21.00   0.986094   11.151379  520       0.0
# 4    11.00    15.00   0.027345  875.144298   14       0.0
# 1    12.50    18.00   0.520148   16.800292    6       0.0
# 3    11.00    17.00   0.571002   16.989335  500       0.0
# 2    11.00    17.00   0.752991    7.051255  496       0.0
# 7    55.75    74.75   0.034486  577.514153   10       0.0
# 5   416.50   543.50   0.190114    5.752836    2       0.0
# 6   125.00   262.25   0.218928    6.945895  496       0.0
# 8   104.00   212.25   0.205952    6.795578  492       0.0

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
#fig_bootstrap_2.savefig('/home/aalvarez/Downloads/Plots/bootstrap_mortgage.eps', bbox_inches='tight')

# %% [markdown]
# ## Maximal EDD found

# %%
pretty_highest_ind(ind_find2)
# Out:
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies

# %%
for k in ind_findq.keys():
    print(k)
    print(pretty_highest_ind(ind_findq[k]))
# Out:
# (0.05, 1000.0, 0)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.1, 1.0, 0)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.05, 1.0, 0)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.0, 1.0, 0)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.05, 1000.0, 1)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket         3Y-CMaturityRate
# 5          3Y-CMaturityRate  3M-Rate-SecondaryMarket
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.05, 1.0, 1)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.0, 1.0, 1)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies
# (0.1, 1.0, 1)
#                mortgage.dat             treasury.dat
# 0              1MonthCDRate             1MonthCDRate
# 1          1Y-CMaturityRate         1Y-CMaturityRate
# 2         30Y-CMortgageRate        30Y-CMortgageRate
# 3    3M-Rate-AuctionAverage   3M-Rate-AuctionAverage
# 4   3M-Rate-SecondaryMarket  3M-Rate-SecondaryMarket
# 5          3Y-CMaturityRate         3Y-CMaturityRate
# 6          5Y-CMaturityRate         5Y-CMaturityRate
# 7                bankCredit               bankCredit
# 8         checkableDeposits        checkableDeposits
# 9                  currency                 currency
# 10           demandDeposits           demandDeposits
# 11             federalFunds             federalFunds
# 12              loansLeases              loansLeases
# 13               moneyStock               moneyStock
# 14          savingsDeposits          savingsDeposits
# 15          tradeCurrencies          tradeCurrencies

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['mortgage_start3_20211004', 'mortgage_start3_20211005']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
h3_stats = general_stats(h3_find2, h3_findq)
h3_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN  10.452187   19.281021   0.80625       1.0    72.00
# 2  FindQ 0    0.05    0.9   9.601743   19.210935   0.81250       1.0    72.75
# 3  FindQ 0    0.10    0.9   9.581542   20.486836   0.81250       1.0    73.00
# 1  FindQ 1    0.05    0.9  42.881931  369.466540   0.81250       1.0   202.00
# 4  FindQ 1    0.10    0.9  49.476480  314.909082   0.81250       1.0   186.50
#
#    Card Q3  Precision  Overhead    N  Timeouts
# 0   147.00   0.993847  2.410878  111  0.224490
# 2   133.25   0.982181  1.165942  144  0.000000
# 3   137.00   0.988314  1.142793  143  0.000000
# 1   403.50   0.984752  1.031891  142  0.006849
# 4   403.50   0.980958  1.045084  142  0.000000

# %%
#fig3.savefig('/home/aalvarez/Downloads/Plots/mortgage_3ind-grow.eps', bbox_inches='tight')

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
#fig_bootstrap_3.savefig('/home/aalvarez/Downloads/Plots/bootstrap_mortgage_start3.eps', bbox_inches='tight')
