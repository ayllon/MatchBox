# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot
import tarfile
import numpy as np

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210628']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/mortgage-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN   0.458637    0.748553  0.784615       1.0    12.50
# 1  FindQ 0    0.05    0.9   0.792356   10.225375  0.875000       1.0    11.00
# 2  FindQ 1    0.05    0.9  35.880829  120.262094  0.937500       1.0   101.75
#
#    Card Q3  Precision   Overhead    N
# 0    21.00   0.989500  15.086284  243
# 1    17.00   0.547106  18.086823  237
# 2   201.75   0.174029   8.781986  238

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['mortgage_start3_20210707']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#     Method  Lambda  Gamma    Time Q1    Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN  13.323860  23.673720  0.765625       1.0     79.0
# 1  FindQ 0    0.05    0.9   6.814479  23.055344  0.861607       1.0     72.5
# 2  FindQ 1    0.05    0.9  10.149528  25.782841  0.861607       1.0     75.5
#
#    Card Q3  Precision  Overhead   N
# 0   156.25   0.999778  2.117637  34
# 1   108.00   0.995205  1.130459  34
# 2   146.25   0.992558  1.008188  34

# %%
fig3.savefig('/home/aalvarez/Downloads/mortgage_3ind-grow.pdf')
