# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot
import tarfile
import numpy as np

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['mortgage_20210628']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/mortgage-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
print(h2_stats.to_markdown())
# Out:
# |    | Method   |   Lambda |   Gamma |   Time Q1 |   Time Q2 |    Time Q3 |   Match Q1 |   Match Q2 |   Match Q3 |   Card Q1 |   Card Q2 |   Card Q3 |   N |
# |---:|:---------|---------:|--------:|----------:|----------:|-----------:|-----------:|-----------:|-----------:|----------:|----------:|----------:|----:|
# |  0 | Find2    |   nan    |   nan   |  0.458637 |  0.551779 |   0.748553 |   0.784615 |     0.875  |          1 |     12.5  |      16   |     21    | 243 |
# |  1 | FindQ 0  |     0.05 |     0.9 |  0.792356 |  1.04479  |  10.2254   |   0.875    |     0.9375 |          1 |     11    |      13   |     17    | 237 |
# |  2 | FindQ 1  |     0.05 |     0.9 | 35.8808   | 78.5753   | 120.262    |   0.9375   |     1      |          1 |    101.75 |     164.5 |    201.75 | 238 |

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['mortgage_start3_20210701']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
print(h3_stats.to_markdown())
# Out:
# |    | Method   |   Lambda |   Gamma |   Time Q1 |   Time Q2 |   Time Q3 |   Match Q1 |   Match Q2 |   Match Q3 |   Card Q1 |   Card Q2 |   Card Q3 |   N |
# |---:|:---------|---------:|--------:|----------:|----------:|----------:|-----------:|-----------:|-----------:|----------:|----------:|----------:|----:|
# |  0 | Find2    |   nan    |   nan   |   5.93598 |   7.42781 |   12.613  |   0.8125   |   0.923077 |          1 |        12 |        17 |        31 |  33 |
# |  1 | FindQ 0  |     0.05 |     0.9 |   6.84264 |  10.6669  |   11.6774 |   0.818182 |   0.9375   |          1 |        11 |        14 |        23 |  33 |
# |  2 | FindQ 1  |     0.05 |     0.9 |   7.06153 |  10.1195  |   12.2515 |   0.818182 |   0.9375   |          1 |        11 |        14 |        23 |  33 |

# %%
fig3.savefig('/home/aalvarez/Downloads/mortgage_3ind.pdf')
