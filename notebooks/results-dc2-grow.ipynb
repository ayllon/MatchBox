# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['dc2_20210628', 'dc2_20210629']
h2_find2, h2_findq = load_results(h2_run_ids)
findq_subset = [(0.05, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/dc2-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#     Method  Lambda  Gamma     Time Q1      Time Q2      Time Q3  Match Q1  \
# 0    Find2     NaN    NaN  357.980813   725.148271  1892.187727  0.645395
# 1  FindQ 0    0.05    0.9  192.497114   217.632980   261.635582  0.842105
# 2  FindQ 1    0.05    0.9  624.910906  1362.869742  2540.281353  0.789474
#
#    Match Q2  Match Q3  Card Q1  Card Q2  Card Q3  N
# 0  0.684211  0.712500    119.0    142.5   187.25  8
# 1  0.842105  0.894737     86.0    130.0   134.00  5
# 2  0.894737  0.894737    507.0    557.0   595.00  5
