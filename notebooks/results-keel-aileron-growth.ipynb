# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['ailerons_20210628']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/ailerons-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
print(h2_stats.to_markdown())
# Out:
# |    | Method   |   Lambda |   Gamma |   Time Q1 |   Time Q2 |   Time Q3 |   Match Q1 |   Match Q2 |   Match Q3 |   Card Q1 |   Card Q2 |   Card Q3 |   N |
# |---:|:---------|---------:|--------:|----------:|----------:|----------:|-----------:|-----------:|-----------:|----------:|----------:|----------:|----:|
# |  0 | Find2    |   nan    |   nan   |   8.04355 |   30.4797 |   64.9081 |   0.777778 |   0.888889 |    1       |    133    |     238   |     358   |  73 |
# |  1 | FindQ 0  |     0.05 |     0.9 |   8.46096 |   14.6384 |   27.5413 |   1        |   1.11111  |    1.22222 |     73.75 |     128   |     201.5 |  68 |
# |  2 | FindQ 1  |     0.05 |     0.9 |  47.8219  |   85.6681 |  183.233  |   1.11111  |   1.125    |    1.25    |    250.25 |     381.5 |     647   |  68 |

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['ailerons_start3_20210701']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
print(h3_stats.to_markdown())
# Out:
# |    | Method   |   Lambda |   Gamma |   Time Q1 |   Time Q2 |   Time Q3 |   Match Q1 |   Match Q2 |   Match Q3 |   Card Q1 |   Card Q2 |   Card Q3 |   N |
# |---:|:---------|---------:|--------:|----------:|----------:|----------:|-----------:|-----------:|-----------:|----------:|----------:|----------:|----:|
# |  0 | Find2    |   nan    |   nan   |   9.84878 |   44.4977 |  303.171  |   0.875    |   0.888889 |    1       |    209.5  |     358   |     521.5 | 219 |
# |  1 | FindQ 0  |     0.05 |     0.9 |   8.8814  |   14.3752 |   26.3376 |   0.888889 |   1        |    1.11111 |    148.5  |     228   |     349   | 216 |
# |  2 | FindQ 1  |     0.05 |     0.9 |  11.3455  |   20.4952 |   39.0847 |   0.888889 |   1        |    1.11111 |    149.25 |     232.5 |     353.5 | 218 |

# %%
fig3.savefig('/home/aalvarez/Downloads/ailerons_3ind.pdf')
