# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = 'ailerons_20210429'
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN    41.402369   65.315062      0.900345     0.128304
# 1  FindQ    0.05    0.9    20.786669   63.673722      1.063923     0.127731
# 2  FindQ    0.10    0.9    27.866693  143.278553      1.051148     0.122771
#
#       N
# 0  1124
# 1  1124
# 2  1124

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'ailerons_start3_20210524'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   268.460319  637.633589      0.919737     0.117213
# 1  FindQ    0.05    0.9    42.855435  126.245230      1.003042     0.120417
# 2  FindQ    0.10    0.9    45.341526  128.214091      0.994418     0.118474
#
#      N
# 0  182
# 1  182
# 2  182
