# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = 'ailerons.dat_elevators.dat_20210112'
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN    51.398177   72.791325      0.889313     0.134180
# 1  FindQ    0.05    0.9    21.219848   26.858620      1.080815     0.127847
# 2  FindQ    0.10    0.9    24.922105   48.038559      1.069519     0.123911
#
#      N
# 0  243
# 1  150
# 2  150

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'ailerons.dat_elevators.dat_3ind_20210120'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)   Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   614.637427  1290.856883      0.898545     0.113242
# 1  FindQ    0.05    0.9    75.736545   185.868658      0.982937     0.117279
# 2  FindQ    0.10    0.9    80.063085   182.931765      0.979116     0.117441
#
#     N
# 0  60
# 1  60
# 2  59
