# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['ailerons_20210429', 'ailerons_20210601', 'ailerons_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 10000, 0)])
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1    Time Q2    Time Q3  Match Q1  \
# 0    Find2     NaN    NaN   6.768271  22.599051  52.814497  0.777778
# 3  FindQ 0    0.00    0.9   9.613698  19.941629  34.696181  1.000000
# 4  FindQ 0    0.05    0.0  21.493604  31.890100  48.879495  1.000000
# 1  FindQ 0    0.05    0.9   7.124769  11.795512  19.395227  1.000000
# 2  FindQ 0    0.10    0.9   6.331535  11.302910  22.305964  1.000000
#
#    Match Q2  Match Q3  Card Q1  Card Q2  Card Q3     N
# 0  0.888889  1.000000   130.00    206.0    317.0  4390
# 3  1.111111  1.222222    81.00    119.0    168.0  2250
# 4  1.111111  1.222222   114.00    170.0    255.0  1007
# 1  1.111111  1.125000    87.75    129.0    184.0  1124
# 2  1.000000  1.125000    91.00    137.0    203.0  1124

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['ailerons_start3_20210524', 'ailerons_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00), (0.05, 1000)])
h3_stats
