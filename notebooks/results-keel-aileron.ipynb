# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = 'ailerons_20210429'
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset, 0.05)
h2_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   102.053615  171.784487      1.013275     0.123639
# 1  FindQ    0.05   0.95    51.455324  363.022859      1.129016     0.119657
# 2  FindQ    0.10   0.95    64.313581  351.074878      1.105139     0.117038
#
#       N
# 0  1124
# 1  1124
# 2  1124

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = 'ailerons_start3_20210503'
h3_find2, h3_findq = load_results(h3_run_id)

# %%
plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#   Method  Lambda  Gamma  Time (mean)  Time (std)  Match (mean)  Match (std)  \
# 0  Find2     NaN    NaN   170.695272  629.910256      0.890338     0.132237
# 1  FindQ    0.05    0.9    47.772859  206.197974      0.927852     0.137525
# 2  FindQ    0.10    0.9    47.309517  205.077797      0.926562     0.136998
#
#       N
# 0  2354
# 1  2353
# 2  2352
