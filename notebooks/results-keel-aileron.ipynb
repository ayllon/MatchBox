# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats, pretty_highest_ind,parse_fields
import plot

plt.style.use('seaborn')
plt.style.use('seaborn-paper')
plt.style.use('tableau-colorblind10')
plt.rcParams.update({
    'figure.figsize': (4.8, 3),
    'text.usetex': True,
    'font.size': 10,
    'ytick.labelsize': 6,
    'xtick.labelsize': 6,
    'axes.labelsize': 10,
    'legend.fontsize': 10,
    'lines.markersize': 5,
    'lines.linewidth': 1,
    'errorbar.capsize': 2
})

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['ailerons_20211001']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
h2_stats = general_stats(h2_find2, h2_findq)
h2_stats
# Out:
#     Method  Lambda  Gamma     Time Q1     Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN    5.625884   48.409501  0.777778  1.000000
# 3  FindQ 0    0.00    0.9   11.353305   37.131190  1.000000  1.222222
# 7  FindQ 0    0.05    0.0   18.544332   61.788191  1.083333  1.149306
# 2  FindQ 0    0.05    0.9    7.513355   20.122576  1.000000  1.111111
# 5  FindQ 0    0.10    0.9    6.827509   22.397582  1.000000  1.111111
# 4  FindQ 1    0.00    0.9  128.571577  991.041442  1.222222  1.333333
# 1  FindQ 1    0.05    0.9   57.862198  674.260989  1.111111  1.250000
# 6  FindQ 1    0.10    0.9   75.333383  502.253555  1.111111  1.222222
#
#    Card Q1  Card Q3  Precision   Overhead   N  Timeouts
# 0   142.00   291.00   0.980912   5.025621  93       0.0
# 3    91.00   184.00   0.238416  15.839217  29       0.0
# 7    66.00   219.75   0.126453  10.830685   4       0.0
# 2    86.00   198.00   0.354003   5.163360  60       0.0
# ...

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
fig_bootstrap_2.savefig('/home/aalvarez/Downloads/Plots/bootstrap_aileron.eps', bbox_inches='tight')

# %% [markdown]
# ## Maximal EDD found

# %%
ind_find2.keys()
# Out:
# dict_keys([8, 7, 9, 6, 5, 3, 4, 10, 2, 11])

# %%
pretty_highest_ind(ind_find2)
# Out:
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime8   DiffSaTime3
# 7              P             P
# 8              Q             Q
# 9       SeTime14          Goal
# 10           Sgz           Sgz

# %%
ind_findq[(0.1, 1.0, 0)].keys()
# Out:
# dict_keys([8, 7, 9, 6, 5, 3, 4, 10, 2, 11])

# %%
for k in ind_findq.keys():
    print(k)
    print(pretty_highest_ind(ind_findq[k]))
# Out:
# (0.05, 1.0, 1)
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime3   DiffSaTime3
# 7    DiffSeTime4   DiffSaTime1
# 8           Goal       SaTime4
# 9              P             P
# 10             Q             Q
# 11      SeTime10          Goal
# 12           Sgz           Sgz
# (0.05, 1.0, 0)
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime3   DiffSaTime3
# 7              P             P
# 8              Q             Q
# 9        SeTime8          Goal
# 10           Sgz           Sgz
# (0.0, 1.0, 0)
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# ...

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['ailerons_start3_20211004']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq)

# %%
h3_stats = general_stats(h3_find2, h3_findq)
h3_stats
# Out:
#     Method  Lambda  Gamma     Time Q1      Time Q3  Match Q1  Match Q3  \
# 0    Find2     NaN    NaN   51.276603  1129.265497  0.888889  1.000000
# 2  FindQ 0    0.05    0.9   27.265798    74.814420  1.000000  1.133929
# 3  FindQ 0    0.10    0.9   27.734549    81.445211  1.000000  1.125000
# 1  FindQ 1    0.05    0.9  160.687267   524.187645  1.111111  1.205357
# 4  FindQ 1    0.10    0.9  174.148897   514.587638  1.111111  1.173611
#
#    Card Q1  Card Q3  Precision  Overhead   N  Timeouts
# 0    609.5    819.5   0.999980  3.382274  15       0.0
# 2    392.5    555.5   0.969783  1.416380  15       0.0
# 3    412.0    571.0   0.969120  1.379815  15       0.0
# 1    741.5   1181.0   0.926020  1.285019  15       0.0
# 4    753.0   1184.0   0.949363  1.218122  15       0.0

# %%
fig3.savefig('/home/aalvarez/Downloads/Plots/ailerons_3ind-grow.eps', bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)])

# %%
fig_bootstrap_3.savefig('/home/aalvarez/Downloads/Plots/bootstrap_aileron_start3.eps', bbox_inches='tight')
