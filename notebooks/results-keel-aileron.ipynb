# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['ailerons_20210429', 'ailerons_20210601', 'ailerons_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00), (0.10, 1.00)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00), (0.05, 10000)])
h2_stats
# Out:
#   Method  Lambda  Gamma    Time Q1    Time Q2    Time Q3   Time IQR  Match Q1  \
# 0  Find2     NaN    NaN   6.768271  22.599051  52.814497  46.046226  0.777778
# 3  FindQ    0.00    0.9   9.613698  19.941629  34.696181  25.082483  1.000000
# 4  FindQ    0.05    0.0  21.493604  31.890100  48.879495  27.385890  1.000000
# 1  FindQ    0.05    0.9   7.124769  11.795512  19.395227  12.270458  1.000000
# 2  FindQ    0.10    0.9   6.331535  11.302910  22.305964  15.974429  1.000000
#
#    Match Q2  Match Q3  Match IQR     N
# 0  0.888889  1.000000   0.222222  4390
# 3  1.111111  1.222222   0.222222  2250
# 4  1.111111  1.222222   0.222222  1007
# 1  1.111111  1.125000   0.125000  1124
# 2  1.000000  1.125000   0.125000  1124

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['ailerons_start3_20210524', 'ailerons_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00), (0.05, 1000)])
h3_stats
# Out:
#   Method  Lambda  Gamma   Time Q1    Time Q2    Time Q3   Time IQR  Match Q1  \
# 0  Find2     NaN    NaN  4.729422  11.222190  71.508136  66.778715  0.777778
# 3  FindQ    0.00    0.9  6.424615  11.918699  21.416721  14.992107  0.875000
# 4  FindQ    0.05    0.0  6.652751  11.128025  19.572330  12.919579  0.888889
# 1  FindQ    0.05    0.9  5.082142   8.798700  17.544959  12.462818  0.875000
# 2  FindQ    0.10    0.9  7.054066  13.137290  22.661037  15.606972  0.888889
#
#    Match Q2  Match Q3  Match IQR     N
# 0  0.888889  1.000000   0.222222  1656
# 3  1.000000  1.111111   0.236111  1472
# 4  1.000000  1.000000   0.111111  1472
# 1  0.888889  1.000000   0.125000  1653
# 2  1.000000  1.083333   0.194444   182
