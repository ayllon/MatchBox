# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats, pretty_highest_ind
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_ids = ['ailerons_20210628'] + ['ailerons_20210429', 'ailerons_20210601', 'ailerons_20210606']
h2_find2, h2_findq, ind_find2, ind_findq = load_results(h2_run_ids, return_inds=True)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0), (0.05, 1.00, 1)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
fig.savefig('/home/aalvarez/Downloads/ailerons-grow.pdf')

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset)
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN   6.769346   53.060477  0.777778     1.000   130.00
# 1  FindQ 0    0.05    0.9   7.152937   19.927699  1.000000     1.125    87.00
# 2  FindQ 0    0.10    0.9   6.335668   22.803553  1.000000     1.125    90.00
# 3  FindQ 1    0.05    0.9  47.821942  183.232504  1.111111     1.250   250.25
#
#    Card Q3  Precision  Overhead     N
# 0    318.0   0.970378  4.880275  4463
# 1    185.0   0.316978  5.741458  1192
# 2    204.0   0.357715  5.007776  1189
# 3    647.0   0.172555  7.376855    68

# %%
fig_bootstrap_2 = plot.bootstrap_plot(h2_find2, h2_findq, findq_subset)

# %%
fig_bootstrap_2.savefig('/home/aalvarez/Downloads/bootstrap_aileron.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Maximal EDD found

# %%
pretty_highest_ind(ind_find2)
# Out:
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime5   DiffSaTime3
# 7           Goal       SaTime2
# 8              P             P
# 9              Q             Q
# 10       SeTime1          Goal
# 11          Sgz)           Sgz

# %%
for k in findq_subset:
    print(k)
    print(pretty_highest_ind(ind_findq[k]))
# Out:
# (0.05, 1.0, 0)
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime4   DiffSaTime3
# 7    DiffSeTime5   DiffSaTime2
# 8           Goal       SaTime2
# 9              P             P
# 10             Q             Q
# 11       SeTime9          Goal
# 12          Sgz)           Sgz
# (0.1, 1.0, 0)
#     ailerons.dat elevators.dat
# 0        AbsRoll       AbsRoll
# 1      ClimbRate     ClimbRate
# 2        CurRoll       CurRoll
# 3        DiffClb       DiffClb
# 4    DiffDiffClb   DiffDiffClb
# 5   DiffRollRate  DiffRollRate
# 6    DiffSeTime4   DiffSaTime3
# 7    DiffSeTime5   DiffSaTime2
# 8           Goal       SaTime3
# 9              P             P
# 10             Q             Q
# 11       SeTime9          Goal
# 12          Sgz)           Sgz
# (0.05, 1.0, 1)
# ...

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_ids = ['ailerons_start3_20210707', 'ailerons_start3_20210708']
h3_find2, h3_findq = load_results(h3_run_ids)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset)
h3_stats
# Out:
#     Method  Lambda  Gamma    Time Q1     Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN  41.338872  899.739732     0.875  1.000000   483.00
# 1  FindQ 0    0.05    0.9  23.463827   54.694596     1.000  1.142857   365.00
# 2  FindQ 0    0.10    0.9  23.524690   54.531808     1.000  1.129464   367.25
# 3  FindQ 1    0.05    0.9  36.314401   86.156246     1.000  1.138393   367.75
#
#    Card Q3  Precision  Overhead   N
# 0   875.00   0.999324  3.112452  39
# 1   591.00   0.979459  1.259887  37
# 2   631.50   0.984853  1.225329  36
# 3   658.25   0.977877  1.031664  38

# %%
fig3.savefig('/home/aalvarez/Downloads/ailerons_3ind-grow.pdf')

# %%
fig_bootstrap_3 = plot.bootstrap_plot(h3_find2, h3_findq, findq_subset)

# %%
fig_bootstrap_3.savefig('/home/aalvarez/Downloads/bootstrap_aileron_start3.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
