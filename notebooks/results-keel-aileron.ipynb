# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import gridspec
from matplotlib import cm

from results import load_results, general_stats
import plot

plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Starting on a 2-hypergraph

# %%
h2_run_id = ['ailerons_20210429', 'ailerons_20210601', 'ailerons_20210606']
h2_find2, h2_findq = load_results(h2_run_id)
findq_subset = [(0.05, 1.00, 0), (0.10, 1.00, 0)]

# %%
fig = plot.plot_comparison(h2_find2, h2_findq, findq_subset)

# %%
h2_stats = general_stats(h2_find2, h2_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 10000, 0)])
h2_stats
# Out:
#     Method  Lambda  Gamma    Time Q1    Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN   6.768271  52.814497  0.777778  1.000000   130.00
# 3  FindQ 0    0.00    0.9   9.613698  34.696181  1.000000  1.222222    81.00
# 4  FindQ 0    0.05    0.0  21.493604  48.879495  1.000000  1.222222   114.00
# 1  FindQ 0    0.05    0.9   7.124769  19.395227  1.000000  1.125000    87.75
# 2  FindQ 0    0.10    0.9   6.331535  22.305964  1.000000  1.125000    91.00
#
#    Card Q3  Precision     N
# 0    317.0   0.970368  4390
# 3    168.0   0.246917  2250
# 4    255.0   0.158763  1007
# 1    184.0   0.318320  1124
# 2    203.0   0.360251  1124

# %% [markdown]
# # Starting on a 3-hypergraph

# %%
h3_run_id = ['ailerons_start3_20210524', 'ailerons_start3_20210611']
h3_find2, h3_findq = load_results(h3_run_id)

# %%
fig3 = plot.plot_comparison(h3_find2, h3_findq, findq_subset)

# %%
h3_stats = general_stats(h3_find2, h3_findq, findq_subset + [(0.00, 1.00, 0), (0.05, 1000, 0)])
h3_stats
# Out:
#     Method  Lambda  Gamma   Time Q1    Time Q3  Match Q1  Match Q3  Card Q1  \
# 0    Find2     NaN    NaN  4.729422  71.508136  0.777778  1.000000    142.0
# 3  FindQ 0    0.00    0.9  6.424615  21.416721  0.875000  1.111111    104.0
# 4  FindQ 0    0.05    0.0  6.652751  19.572330  0.888889  1.000000    107.0
# 1  FindQ 0    0.05    0.9  5.082142  17.544959  0.875000  1.000000    114.0
# 2  FindQ 0    0.10    0.9  7.054066  22.661037  0.888889  1.083333    144.0
#
#    Card Q3  Precision     N
# 0   360.00   0.999186  1656
# 3   256.50   0.649063  1472
# 4   261.00   0.748932  1472
# 1   288.00   0.976897  1653
# 2   339.75   0.976334   182
